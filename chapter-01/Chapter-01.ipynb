# %%
with open("datasets/rosalind_ba1a.txt") as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['...\n',
#  'AGACTGGAG\n']

# %%
def PatternCount(text, pattern):
    count = 0
    for i in range(len(text) - len(pattern)+1):
        if text[i:(i+len(pattern))] == pattern:
            count += 1
    return count

# %%
PatternCount("ABCABC", "ABC")
# Out:
# 2

# %%
PatternCount("...","TGCAGTCTG")
# Out:
# 32
